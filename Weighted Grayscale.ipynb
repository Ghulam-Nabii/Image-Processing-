# %% [markdown]
# # Weighted Grayscale
# Average grayscale doesn't usually look very natural.
# A more natural alternative consists in assigning different weights to Red, Green, and Blue, based on luminance or human perception.
#
# A popular distribution is:
# * Red: 0.299
# * Green: 0.587
# * Blue: 0.114

# %%
# Let's open the Playspace image again

import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = 'retina'
# %matplotlib inline
from EC_CV import *
from matplotlib import rcParams

plt.rcParams['figure.figsize'] = (8, 8)

toys = adapt_PNG(plt.imread('playspace.png'))
plt.axis("off")
plt.imshow(toys)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_34107/2356098865.py in <module>
#       5 get_ipython().run_line_magic('config', "InlineBackend.figure_formats = 'retina'")
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 7 from EC_CV import *
#       8 from matplotlib import rcParams
#       9
#
# ModuleNotFoundError: No module named 'EC_CV'

# %%
rcParams['figure.figsize'] = (20, 8)

# Calculate regular average and weighted average
toys_avg = np.dot(toys[...,:3], [1/3,1/3,1/3])
toys_wgt = np.dot(toys[...,:3], [0.299,0.587,0.114])

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(toys_avg, cmap='gray')
ax[1].imshow(toys_wgt, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_34107/2370344244.py in <module>
# ----> 1 rcParams['figure.figsize'] = (20, 8)
#       2
#       3 # Calculate regular average and weighted average
#       4 toys_avg = np.dot(toys[...,:3], [1/3,1/3,1/3])
#       5 toys_wgt = np.dot(toys[...,:3], [0.299,0.587,0.114])
#
# NameError: name 'rcParams' is not defined

# %%
# Now let's try it on another picture

fruit = plt.imread('fruit.jpg')
plt.imshow(fruit)

# %%
fruit_avg = np.dot(fruit[...,:3], [1/3,1/3,1/3])
fruit_wgt = np.dot(fruit[...,:3], [0.299,0.587,0.114])

# figure size in inches
rcParams['figure.figsize'] = 20, 8

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(fruit_avg, cmap='gray')
ax[1].imshow(fruit_wgt, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5h/h4vpmp015hj4llck4ly707n40000gn/T/ipykernel_34107/884349973.py in <module>
#       3
#       4 # figure size in inches
# ----> 5 rcParams['figure.figsize'] = 20, 8
#       6
#       7 # display images
#
# NameError: name 'rcParams' is not defined
